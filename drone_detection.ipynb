# %%
import tensorflow as tf
from tensorflow import keras

# %%
print("TensorFlow version:", tf.__version__)
print("Built with GPU support:", tf.test.is_built_with_gpu_support())
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.16.2
# Built with GPU support: False
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import glob
from lxml import etree
import cv2

# %%
from csv_to_yolo import convert_csv_to_yolo

# %%
class_map = {
    "Drone": 0,
    "Helicopter": 1,
    "AirPlane": 2
}

base_dir = '/Users/akshar/Documents/DL/drone detection/data'

# %% [markdown]
# ### converting csv to yolo

# %%
convert_csv_to_yolo(base_dir, class_map)
# Out:
# ✅ Converted train_labels.csv to YOLO format in /Users/akshar/Documents/DL/drone detection/data/labels/train
# ✅ Converted val_labels.csv to YOLO format in /Users/akshar/Documents/DL/drone detection/data/labels/val
# ✅ Converted test_labels.csv to YOLO format in /Users/akshar/Documents/DL/drone detection/data/labels/test

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')

# %%
model.train(
    data="/Users/akshar/Documents/DL/drone detection/dataset.yaml",
    epochs=10,
    batch=32,
    imgsz=512,
    patience=5,              # Early stopping
    val=False,                
    name="drone_detector_n",
    project="runs_n/drone_train_n",
    device='mps',
    verbose=True,
    exist_ok=True,
    save=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.156 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.155 🚀 Python-3.10.18 torch-2.7.1 MPS (Apple M3)
# ...

# %%
model = YOLO('/Users/akshar/Documents/DL/drone detection/runs_n/drone_train_n/drone_detector_n/weights/best.pt')
model.conf = 0.5     
model.iou = 0.45      
model.classes = [0, 1]

# %%
metrics = model.val(data='/Users/akshar/Documents/DL/drone detection/dataset.yaml')
print(metrics)
# Out:
# Ultralytics 8.3.155 🚀 Python-3.10.18 torch-2.7.1 CPU (Apple M3)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 91.5±26.3 MB/s, size: 13.1 KB)
# val: Scanning /Users/akshar/Documents/DL/drone detection/data/labels/val.cache..
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        603        497      0.914      0.925      0.942      0.579
#                  Drone        220        224      0.871      0.871      0.869      0.426
#             Helicopter        140        140      0.985      0.964       0.99       0.66
#               AirPlane        133        133      0.885       0.94      0.968       0.65
# Speed: 0.3ms preprocess, 81.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  


# Load training results
df = pd.read_csv('/Users/akshar/Documents/DL/drone detection/runs_n/drone_train_n/drone_detector_n/results.csv')

# Show the last few epochs
display(df.tail())

# Plot training vs validation metrics
metrics = ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 
           'train/box_loss', 'train/cls_loss', 'train/dfl_loss']

plt.figure(figsize=(15, 10))
for i, m in enumerate(metrics, 1):
    plt.subplot(3, 3, i)
    plt.plot(df[m], label=m, marker='o')
    plt.title(m)
    plt.xlabel("Epoch")
    plt.grid()
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 5      6  2899.29         1.55685         1.05978         1.18917
# 6      7  3446.73         1.51924         1.00659         1.16595
# 7      8  4053.53         1.47425         0.96436         1.14049
# 8      9  4676.48         1.42712         0.89510         1.12378
# 9     10  5413.39         1.39339         0.86037         1.10461
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 5               0.00000            0.00000           0.00000
# 6               0.00000            0.00000           0.00000
# 7               0.00000            0.00000           0.00000
# 8               0.00000            0.00000           0.00000
# 9               0.88838            0.42383           0.46191
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 5              0.00000       0.00000       0.00000        0.0000  0.000722
# ...

# %%
from PIL import Image
results = model('/Users/akshar/Documents/DL/drone detection/test.jpg')         ## in this path give you own path of your own image

r = results[0]

annotated_frame = r.plot()

# Convert to PIL image if needed (optional)
# img = Image.fromarray(annotated_frame)

plt.figure(figsize=(8, 6))
plt.imshow(annotated_frame)
plt.axis('off')
plt.title("Detection Result")
plt.show()
# Out:
# image 1/1 /Users/akshar/Documents/DL/drone detection/test.jpg: 512x512 2 Helicopters, 50.2ms
# Speed: 5.2ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 512)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load training logs
df = pd.read_csv('/Users/akshar/Documents/DL/drone detection/runs_n/drone_train_n/drone_detector_n/results.csv')

# Clean column names (good practice)
df.columns = df.columns.str.strip()

# Plot Precision, Recall, and mAP@0.5
plt.figure(figsize=(10, 4))
plt.plot(df['metrics/precision(B)'], label='Precision')
plt.plot(df['metrics/recall(B)'], label='Recall')
plt.plot(df['metrics/mAP50(B)'], label='mAP@0.5')
plt.plot(df['metrics/mAP50-95(B)'], label='mAP@0.5:0.95')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.title('Model Performance Metrics')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def smooth_curve(values, weight=0.8):
    """Applies exponential moving average smoothing."""
    smoothed = []
    last = values[0]
    for point in values:
        smoothed_val = last * weight + (1 - weight) * point
        smoothed.append(smoothed_val)
        last = smoothed_val
    return smoothed

# %%
box_loss_smoothed = smooth_curve(df['train/box_loss'])
val_box_loss_smoothed = smooth_curve(df['val/box_loss'])
mAP50_smoothed = smooth_curve(df['metrics/mAP50(B)'])

# === Plot: Smoothed Box Losses ===
plt.figure(figsize=(10, 5))
plt.plot(box_loss_smoothed, label='Train Box Loss (Smooth)')
plt.plot(val_box_loss_smoothed, label='Val Box Loss (Smooth)', linestyle='--')
plt.title('Smoothed Box Losses Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
